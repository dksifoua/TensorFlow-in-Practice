# %%
import tensorflow as tf

# %%
# help(tf.keras.callbacks.Callback)

# %%
class StopTrainingCallback(tf.keras.callbacks.Callback):
  
  def on_epoch_end(self, epoch, logs=None):
    if logs.get('acc') > 0.99:
      print('\nReached 99% of accuracy, so cancelling training')
      self.model.stop_training = True

# %%
# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
# Normalize data
x_train = x_train / 255
x_test = x_test / 255

# %%
# Build the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(units=512, activation=tf.nn.relu),
    tf.keras.layers.Dense(units=10, activation=tf.nn.softmax)
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0816 21:33:25.415918 140023798712192 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model
history = model.fit(x_train, y_train, epochs=10, callbacks=[StopTrainingCallback()])
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 17s 276us/sample - loss: 0.2008 - acc: 0.9409
# Epoch 2/10
# 60000/60000 [==============================] - 16s 273us/sample - loss: 0.0802 - acc: 0.9758
# Epoch 3/10
# 60000/60000 [==============================] - 17s 276us/sample - loss: 0.0510 - acc: 0.9842
# Epoch 4/10
# 60000/60000 [==============================] - 16s 269us/sample - loss: 0.0383 - acc: 0.9875
# Epoch 5/10
# 59936/60000 [============================>.] - ETA: 0s - loss: 0.0272 - acc: 0.9916
# Reached 99% of accuracy, so cancelling training
# 60000/60000 [==============================] - 16s 264us/sample - loss: 0.0272 - acc: 0.9916
